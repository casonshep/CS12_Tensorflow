# %% [markdown]
# # Lab 3: Mapping with Fully-Connected Networks
# Blocks of dense layers are really good at memorizing patterns.
# This week we'll step outside the traditional "prediction" regime of machine learning and use a fully-connected network (FCN) to represent a 2-D scene in its weight by interpolating between known points.
#
# Throughout, you should be impressed by two (related) properties of dense neural nets:
#  - They have high enough capacity to entirely memorize complex patterns
#  - They are sufficiently nonlinear to build these patterns up from simple inputs (like (x, y) coordinates in this case)

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Pointcloud mapping
#
# ![full scene](./images/full_scene.png)
#
# ### The problem
# Imagine there is a square (2-D) room with four walls and several square and circular objects in it.
# We put laser distance sensors around the room, which shoot rays that continue until they hit an object or a wall and report the distance, with limited angular and radial resolution.
# We want to use this limited data to produce a full 2-D reconstruction of the scene, filling in points the sensors haven't observed with likely values (in essence, interpolating).
#
# ### The data
# We know that every ray that there's an object at the point each ray hit, and we also know that there's no object between the camera and the contact point.
# The data is provided as (x, y) pairs, where some points correspond to places we know are on object boundaries (shown in green above) and points we know are not inside objects (shown in red above).
#
# These points come in two data files: `data/positives.txt` for points on the edge of objects, and `data/negatives.txt` for points outside of objects.
# To generate these files, run `make_data.py`.
#
# (Check out the code if you want to see how the points are generated, but don't change anything!)
#
# ### The model
# We want to store a full description of the scene in the weights of a neural network.
# To do this, we'll train a FCN to classify (x, y) points by whether or not they are the edge of a wall or object.
# Then, we can draw the scene by sampling (x, y) pairs and drawing the model's output.
# So, the network has "memorized" where the objects and walls are, and what their shapes are.

# %% [markdown]
# # Section 1: Load the data
# Load the data using `np.loadtxt()` (default arguments should work), then convert it to a usable format with a feature array and label array, which is 1 if a point is the edge of an object and 0 if it is not.
#
# Functions to look at:
#  - `np.loadtxt`
#  - `np.concatenate`

# %%
# Your code here

# Load the data from the text files
positive_data = np.loadtxt(r'data/positives.txt', dtype=np.float32)  # Each line should be a coordinate (x, y)
negative_data = np.loadtxt(r'data/negatives.txt', dtype=np.float32)  # Same format for negative data

# Create feature arrays (coordinates)
positive_features = positive_data  # Shape: (n_positive, 2) where each row is (x, y)
negative_features = negative_data  # Shape: (n_negative, 2)

# Create label arrays (1 for positive, 0 for negative)
positive_labels = np.ones(positive_features.shape[0], dtype=np.float32)  # Label 1 for positive data
negative_labels = np.zeros(negative_features.shape[0], dtype=np.float32)  # Label 0 for negative data

# Combine the positive and negative data into a single dataset
features = np.concatenate((positive_features, negative_features), axis=0)
labels = np.concatenate((positive_labels, negative_labels), axis=0)

# Now, `features` contains all the coordinates and `labels` contains the corresponding labels

# %% [markdown]
# # Section 2: Build a data pipeline
# Set up a `tf.data.Dataset` and a `tf.summary.SummaryWriter`.
# This time, there's no test set, just a single dataset. You may want to use the `repeat` method on the dataset for the number of desired epochs. If so, call it after caching so as not to store redundant data.

# %%
# Assume features and labels are already created as NumPy arrays
# features: shape (N, 2), labels: shape (N,)

# Create the dataset
dataset = tf.data.Dataset.from_tensor_slices((features, labels))

# Shuffle, cache, and batch the dataset
batch_size = 32
dataset = dataset.shuffle(buffer_size=1000)  # Shuffle the data
dataset = dataset.cache()                    # Cache for performance
# dataset = dataset.repeat(50)                 # Repeat for 10 epochs
dataset = dataset.batch(batch_size)          # Batch the data

# Set up the TensorBoard SummaryWriter
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
summary_writer = tf.summary.create_file_writer(log_dir)

# Optionally, log some sample data (e.g., first batch)
for batch_features, batch_labels in dataset.take(1):
    with summary_writer.as_default():
        tf.summary.scalar("batch_sample_label", batch_labels[0], step=0)
        tf.summary.histogram("batch_features", batch_features, step=0)

# %% [markdown]
# # Section 3: Build a model graph
# The model is a simple fully-connected neural network with four hidden layers, each with 64 units, and an output layer that performs binary classification with sigmoid activation.
# Recall that the input is just a pair (x, y).
#
# Functions to look at throughout:
#  - `tf.cast`
#  - `tf.expand_dims`
#  - `tf.squeeze`
#  - arithmetic operations

# %% [markdown]
# ### 3.1: Class to make dense layers
# It's tedious (and bad design) to explicitly write out every variable, matrix multiplication, etc.
# Instead, it's common to define classes that create one of a structure you expect to repeat in your model.
#
# Write a `tf.Module` class called `Dense`, which has its signature and scopes defined as a stub below.
# When called, it should add variables and operations to the graph which implement a single dense layer.
#
# If `do_activation` is True, it should apply ReLU activation to the computed values.
# To do this, you can use `tf.nn.relu`.

# %%
class Dense(tf.Module):
    '''
    Creates a dense layer module.

    Parameters
    ----------
    dim_input: int
        Number of features in the input representation.
    dim_output: int
        Number of features in the output representation.
    do_activation: bool
        Whether or not to apply ReLU activation.
    postfix: string
        Postfix on name scopes in this layer.
    name: string
        Name of layer.
    '''
    def __init__(self, dim_input, dim_output, do_activation=True, postfix='', name=None):
        super().__init__(name=name)
        self.do_activation = do_activation
        self.dim_input = dim_input
        self.dim_output = dim_output

        with tf.name_scope('dense' + postfix):
            # Weight matrix shape: [input_dim, output_dim]
            self.w = tf.Variable(
                tf.random.normal([dim_input, dim_output], stddev=0.1),
                name='weights'
            )
            # Bias vector shape: [output_dim]
            self.b = tf.Variable(
                tf.zeros([dim_output]),
                name='bias'
            )

    def __call__(self, x):
        z = tf.matmul(x, self.w) + self.b
        if self.do_activation:
            return tf.nn.relu(z)
        return z

# %% [markdown]
# ### 3.2: Class to make neural network
# Use the `Dense` class to make four dense layers contained as fields in a `tf.Module` class called `FeedForward`.
# Each should have 64 units, the correct input dimensions, and a distinct (and meaningful) postfix.

# %% [markdown]
# #### 3.2.1: Compute logit
# Use the `Dense` class to make a final dense layer with `dim_output=1` to compute the final logit. You'll want to put this in a method called `logits` which should take in `self` and an input.

# %% [markdown]
# #### 3.2.2: Compute class probability for output
# Use `tf.sigmoid` to compute the probability that the input coordinate is a boundary point.
# We will not use this for the loss, just for the output. You'll want to put this in the `__call__` method.

# %%
class FeedForward(tf.Module):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.dense1 = Dense(dim_input=2, dim_output=64, do_activation=True, postfix='_1')
        self.dense2 = Dense(dim_input=64, dim_output=64, do_activation=True, postfix='_2')
        self.dense3 = Dense(dim_input=64, dim_output=64, do_activation=True, postfix='_3')
        self.dense4 = Dense(dim_input=64, dim_output=64, do_activation=True, postfix='_4')
        # Output layer without activation (logit)
        self.output_layer = Dense(dim_input=64, dim_output=1, do_activation=False, postfix='_out')

    def logits(self, x):
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.output_layer(x)

    def __call__(self, x):
        # Get logits and pass through sigmoid to get probabilities
        logit = self.logits(x)
        return tf.sigmoid(logit)
    
    def _loss(self, x, y):
        # Ensure labels are the right shape (batch_size, 1)
        y = tf.cast(tf.expand_dims(y, axis=1), tf.float32)
        logit = self.logits(x)

        loss_per_example = tf.nn.weighted_cross_entropy_with_logits(
            labels=y,
            logits=logit,
            pos_weight=20.0  # Weight positive (boundary) labels more
        )

        # reduce mean
        return tf.reduce_mean(loss_per_example)

# %% [markdown]
# ### 3.3: Compute weighted cross-entropy loss
# There are about 33 times as many non-boundary coordinates as there are boundary coordinates.
# To prevent the network from just learning to predict that every coordinate is not a boundary, we should weight the loss function to consider boundary pixels more heavily.
#
# To do this, use `tf.nn.weighted_cross_entropy_with_logits()` on the logits computed before, plus the input label, and a positive weight of 20.
# Then, produce the mean loss for the batch with `tf.reduce_mean`. Put this in a `_loss` method.

# %% [markdown]
# ### 3.4: Optimizer and gradients
# Make an optimizer (I used `tf.optimizers.SGD` with `learning_rate=2e-3` and `momentum=0.9`).
# Then write a train method (taking in a model, input, output, and step), that represents one step of training, where you explicitly compute the gradients in a variable called `gradients` (so we can plot them below) and make an operation that applies those gradients to the graph.
#
# Note: don't use `optimizer.minimize`, which will result in computing the gradients twice since we already have them from `GradientTape.gradient`. Add a summary scalar to plot loss in TensorBoard.

# %%
# Your code here
optimizer = tf.optimizers.SGD(learning_rate=2e-3, momentum=0.9)


def train_step(model, x, y, step, summary_writer):
    with tf.GradientTape() as tape:
        loss = model._loss(x, y)
    
    # Compute gradients with respect to trainable variables
    gradients = tape.gradient(loss, model.trainable_variables)
    
    # Apply gradients
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    # Log the loss to TensorBoard
    with summary_writer.as_default():
        tf.summary.scalar('train_loss', loss, step=step)
        for gradient, variable in zip(gradients, model.trainable_variables):
            if variable.name and gradient is not None:
                tf.summary.histogram('gradients/' + variable.name, tf.norm(gradient), step=step)
                tf.summary.histogram('variables/' + variable.name, tf.norm(variable), step=step)
    return loss, gradients

# %% [markdown]
# #### 3.4.1: Plot variables and gradients
# You don't need to do this for every model, but it's illustrative to do at least once. I've written the code for this below, with a pattern borrowed from http://matpalm.com/blog/viz_gradient_norms/. Put this code snippet under the same `with` block where you add your loss summary scalar.
#
# ```
# for gradient, variable in zip(gradients, model.trainable_variables):
#     if variable.name and gradient is not None:
#         tf.summary.histogram('gradients/' + variable.name, tf.norm(gradient), step=i)
#         tf.summary.histogram('variables/' + variable.name, tf.norm(variable), step=i)
# ```

# %%
# Your code here

# %% [markdown]
# # Section 4: train the model
# Same as last time, except there's no test set.
# You don't need to distinguish between epochs and steps here.
#
# I used 50 epochs, and got a final cross-entropy loss of about 0.4.
# You might not need to use this many epochs to get reasonable results, but more will get crisper results.
#
# This might take a while on CPUs, so if it's taking too long, think about:
#  - Using Google Colaboratory
#  - Increasing your batch size
#  - Reducing the frequency with which you run summary ops
#
# Watching plots, histograms, etc in TensorBoard as the model trains can be fun.

# %%
# Your code here

# Instantiate model and summary writer
model = FeedForward()
summary_writer = tf.summary.create_file_writer("logs/train")

# Training loop
num_steps = (28556 // batch_size)  # Roughly 50 epochs

step = 0
for i in range(50):
    for batch_features, batch_labels in dataset.take(num_steps):
        loss, gradients = train_step(model, batch_features, batch_labels, step, summary_writer)

        # Optionally print progress
        if step % 100 == 0:
            print(f"Step {step}, Loss: {loss.numpy():.4f}")

        step += 1
# Out:
# Step 0, Loss: 11.4195
# Step 100, Loss: 1.5978
# Step 200, Loss: 0.6000
# Step 300, Loss: 0.2147
# Step 400, Loss: 0.0758
# Step 500, Loss: 0.0333
# Step 600, Loss: 0.0162
# Step 700, Loss: 0.0113
# Step 800, Loss: 0.0077
# Step 900, Loss: 12.0830
# Step 1000, Loss: 1.9092
# Step 1100, Loss: 0.7303
# Step 1200, Loss: 0.2315
# Step 1300, Loss: 0.0602
# Step 1400, Loss: 0.0214
# Step 1500, Loss: 0.0128
# Step 1600, Loss: 0.0083
# Step 1700, Loss: 0.0059
# Step 1800, Loss: 4.2224
# Step 1900, Loss: 1.5926
# Step 2000, Loss: 0.5574
# Step 2100, Loss: 0.1780
# Step 2200, Loss: 0.0697
# Step 2300, Loss: 0.0364
# Step 2400, Loss: 0.0221
# Step 2500, Loss: 0.0152
# Step 2600, Loss: 0.0113
# Step 2700, Loss: 3.0477
# Step 2800, Loss: 1.6348
# Step 2900, Loss: 0.6966
# Step 3000, Loss: 0.3502
# Step 3100, Loss: 0.2044
# Step 3200, Loss: 0.1302
# Step 3300, Loss: 0.0880
# Step 3400, Loss: 0.0624
# Step 3500, Loss: 0.0463
# Step 3600, Loss: 2.2371
# Step 3700, Loss: 1.3560
# Step 3800, Loss: 0.5847
# Step 3900, Loss: 0.2739
# Step 4000, Loss: 0.1419
# Step 4100, Loss: 0.0821
# Step 4200, Loss: 0.0523
# Step 4300, Loss: 0.0361
# Step 4400, Loss: 0.0265
# Step 4500, Loss: 2.2124
# Step 4600, Loss: 1.3275
# Step 4700, Loss: 0.6074
# Step 4800, Loss: 0.3175
# Step 4900, Loss: 0.1914
# Step 5000, Loss: 0.1253
# Step 5100, Loss: 0.0870
# Step 5200, Loss: 0.0630
# Step 5300, Loss: 0.0475
# Step 5400, Loss: 2.0732
# Step 5500, Loss: 1.4110
# Step 5600, Loss: 0.5752
# Step 5700, Loss: 0.3197
# Step 5800, Loss: 0.2110
# Step 5900, Loss: 0.1548
# Step 6000, Loss: 0.1213
# Step 6100, Loss: 0.0993
# Step 6200, Loss: 0.0838
# Step 6300, Loss: 2.1327
# Step 6400, Loss: 1.1440
# Step 6500, Loss: 0.5421
# Step 6600, Loss: 0.3071
# Step 6700, Loss: 0.2050
# Step 6800, Loss: 0.1513
# Step 6900, Loss: 0.1191
# Step 7000, Loss: 0.0978
# Step 7100, Loss: 0.0827
# Step 7200, Loss: 2.0740
# Step 7300, Loss: 1.0667
# Step 7400, Loss: 0.5050
# Step 7500, Loss: 0.2918
# Step 7600, Loss: 0.1974
# Step 7700, Loss: 0.1470
# Step 7800, Loss: 0.1163
# Step 7900, Loss: 0.0959
# Step 8000, Loss: 0.0814
# Step 8100, Loss: 2.0683
# Step 8200, Loss: 0.9998
# Step 8300, Loss: 0.4833
# Step 8400, Loss: 0.2831
# Step 8500, Loss: 0.1931
# Step 8600, Loss: 0.1445
# Step 8700, Loss: 0.1147
# Step 8800, Loss: 0.0947
# Step 8900, Loss: 0.0805
# Step 9000, Loss: 2.0151
# Step 9100, Loss: 1.2251
# Step 9200, Loss: 0.4620
# Step 9300, Loss: 0.2742
# Step 9400, Loss: 0.1886
# Step 9500, Loss: 0.1419
# Step 9600, Loss: 0.1130
# Step 9700, Loss: 0.0935
# Step 9800, Loss: 0.0797
# Step 9900, Loss: 1.9326
# Step 10000, Loss: 0.8772
# Step 10100, Loss: 0.4326
# Step 10200, Loss: 0.2618
# Step 10300, Loss: 0.1822
# Step 10400, Loss: 0.1381
# Step 10500, Loss: 0.1105
# Step 10600, Loss: 0.0918
# Step 10700, Loss: 0.0784
# Step 10800, Loss: 1.7972
# Step 10900, Loss: 0.8395
# Step 11000, Loss: 0.4197
# Step 11100, Loss: 0.2563
# Step 11200, Loss: 0.1794
# Step 11300, Loss: 0.1364
# Step 11400, Loss: 0.1094
# Step 11500, Loss: 0.0910
# Step 11600, Loss: 30.8456
# Step 11700, Loss: 1.7393
# Step 11800, Loss: 0.7691
# Step 11900, Loss: 0.3952
# Step 12000, Loss: 0.2457
# Step 12100, Loss: 0.1737
# Step 12200, Loss: 0.1330
# Step 12300, Loss: 0.1071
# Step 12400, Loss: 0.0895
# Step 12500, Loss: 15.1439
# Step 12600, Loss: 1.7603
# Step 12700, Loss: 0.7425
# Step 12800, Loss: 0.3823
# Step 12900, Loss: 0.2399
# Step 13000, Loss: 0.1707
# Step 13100, Loss: 0.1311
# Step 13200, Loss: 0.1059
# Step 13300, Loss: 0.0886
# Step 13400, Loss: 5.5803
# Step 13500, Loss: 1.7006
# Step 13600, Loss: 0.6957
# Step 13700, Loss: 0.3688
# Step 13800, Loss: 0.2339
# Step 13900, Loss: 0.1674
# Step 14000, Loss: 0.1291
# Step 14100, Loss: 0.1046
# Step 14200, Loss: 0.0876
# Step 14300, Loss: 3.0365
# Step 14400, Loss: 1.4122
# Step 14500, Loss: 0.6588
# Step 14600, Loss: 0.3574
# Step 14700, Loss: 0.2288
# Step 14800, Loss: 0.1647
# Step 14900, Loss: 0.1274
# Step 15000, Loss: 0.1034
# Step 15100, Loss: 0.0868
# Step 15200, Loss: 2.4405
# Step 15300, Loss: 1.3202
# Step 15400, Loss: 0.6112
# Step 15500, Loss: 0.3348
# Step 15600, Loss: 0.2182
# Step 15700, Loss: 0.1588
# Step 15800, Loss: 0.1238
# Step 15900, Loss: 0.1010
# Step 16000, Loss: 0.0850
# Step 16100, Loss: 2.0405
# Step 16200, Loss: 1.2449
# Step 16300, Loss: 0.5828
# Step 16400, Loss: 0.3244
# Step 16500, Loss: 0.2133
# Step 16600, Loss: 0.1560
# Step 16700, Loss: 0.1221
# Step 16800, Loss: 0.0998
# Step 16900, Loss: 0.0842
# Step 17000, Loss: 2.0904
# Step 17100, Loss: 1.1706
# Step 17200, Loss: 0.5518
# Step 17300, Loss: 0.3104
# Step 17400, Loss: 0.2066
# Step 17500, Loss: 0.1523
# Step 17600, Loss: 0.1197
# Step 17700, Loss: 0.0982
# Step 17800, Loss: 0.0830
# Step 17900, Loss: 2.0966
# Step 18000, Loss: 1.0961
# Step 18100, Loss: 0.5282
# Step 18200, Loss: 0.3016
# Step 18300, Loss: 0.2023
# Step 18400, Loss: 0.1498
# Step 18500, Loss: 0.1181
# Step 18600, Loss: 0.0971
# Step 18700, Loss: 0.0822
# Step 18800, Loss: 2.0159
# Step 18900, Loss: 1.2752
# Step 19000, Loss: 0.4955
# Step 19100, Loss: 0.2879
# Step 19200, Loss: 0.1955
# Step 19300, Loss: 0.1459
# Step 19400, Loss: 0.1156
# Step 19500, Loss: 0.0954
# Step 19600, Loss: 0.0810
# Step 19700, Loss: 2.0379
# Step 19800, Loss: 0.9808
# Step 19900, Loss: 0.4705
# Step 20000, Loss: 0.2777
# Step 20100, Loss: 0.1904
# Step 20200, Loss: 0.1429
# Step 20300, Loss: 0.1137
# Step 20400, Loss: 0.0940
# Step 20500, Loss: 0.0800
# Step 20600, Loss: 2.0042
# Step 20700, Loss: 0.9081
# Step 20800, Loss: 0.4456
# Step 20900, Loss: 0.2674
# Step 21000, Loss: 0.1851
# Step 21100, Loss: 0.1398
# Step 21200, Loss: 0.1116
# Step 21300, Loss: 0.0926
# Step 21400, Loss: 0.0790
# Step 21500, Loss: 1.9517
# Step 21600, Loss: 0.8529
# Step 21700, Loss: 0.4270
# Step 21800, Loss: 0.2595
# Step 21900, Loss: 0.1810
# Step 22000, Loss: 0.1373
# Step 22100, Loss: 0.1100
# Step 22200, Loss: 0.0915
# Step 22300, Loss: 37.2246
# Step 22400, Loss: 1.7423
# Step 22500, Loss: 0.8162
# Step 22600, Loss: 0.4124
# Step 22700, Loss: 0.2532
# Step 22800, Loss: 0.1777
# Step 22900, Loss: 0.1354
# Step 23000, Loss: 0.1087
# Step 23100, Loss: 0.0906
# Step 23200, Loss: 24.6107
# Step 23300, Loss: 1.7913
# Step 23400, Loss: 0.7552
# Step 23500, Loss: 0.3879
# Step 23600, Loss: 0.2424
# Step 23700, Loss: 0.1720
# Step 23800, Loss: 0.1319
# Step 23900, Loss: 0.1064
# Step 24000, Loss: 0.0890
# Step 24100, Loss: 9.4405
# Step 24200, Loss: 1.7318
# Step 24300, Loss: 0.7126
# Step 24400, Loss: 0.3739
# Step 24500, Loss: 0.2362
# Step 24600, Loss: 0.1687
# Step 24700, Loss: 0.1299
# Step 24800, Loss: 0.1051
# Step 24900, Loss: 0.0880
# Step 25000, Loss: 5.1611
# Step 25100, Loss: 1.5673
# Step 25200, Loss: 0.6694
# Step 25300, Loss: 0.3568
# Step 25400, Loss: 0.2284
# Step 25500, Loss: 0.1644
# Step 25600, Loss: 0.1273
# Step 25700, Loss: 0.1033
# Step 25800, Loss: 0.0868
# Step 25900, Loss: 2.0536
# Step 26000, Loss: 1.3710
# Step 26100, Loss: 0.6301
# Step 26200, Loss: 0.3406
# Step 26300, Loss: 0.2209
# Step 26400, Loss: 0.1603
# Step 26500, Loss: 0.1247
# Step 26600, Loss: 0.1016
# Step 26700, Loss: 0.0855
# Step 26800, Loss: 2.1937
# Step 26900, Loss: 1.2938
# Step 27000, Loss: 0.6040
# Step 27100, Loss: 0.3306
# Step 27200, Loss: 0.2162
# Step 27300, Loss: 0.1577
# Step 27400, Loss: 0.1231
# Step 27500, Loss: 0.1005
# Step 27600, Loss: 0.0847
# Step 27700, Loss: 2.2531
# Step 27800, Loss: 1.2072
# Step 27900, Loss: 0.5599
# Step 28000, Loss: 0.3136
# Step 28100, Loss: 0.2081
# Step 28200, Loss: 0.1531
# Step 28300, Loss: 0.1202
# Step 28400, Loss: 0.0985
# Step 28500, Loss: 0.0833
# Step 28600, Loss: 2.1653
# Step 28700, Loss: 1.1319
# Step 28800, Loss: 0.5344
# Step 28900, Loss: 0.3036
# Step 29000, Loss: 0.2049
# Step 29100, Loss: 0.1513
# Step 29200, Loss: 0.1191
# Step 29300, Loss: 0.0977
# Step 29400, Loss: 0.0827
# Step 29500, Loss: 2.1706
# Step 29600, Loss: 1.0600
# Step 29700, Loss: 0.5064
# Step 29800, Loss: 0.2940
# Step 29900, Loss: 0.1985
# Step 30000, Loss: 0.1476
# Step 30100, Loss: 0.1167
# Step 30200, Loss: 0.0961
# Step 30300, Loss: 0.0816
# Step 30400, Loss: 1.9642
# Step 30500, Loss: 1.2556
# Step 30600, Loss: 0.4835
# Step 30700, Loss: 0.2831
# Step 30800, Loss: 0.1931
# Step 30900, Loss: 0.1445
# Step 31000, Loss: 0.1147
# Step 31100, Loss: 0.0947
# Step 31200, Loss: 0.0805
# Step 31300, Loss: 2.0606
# Step 31400, Loss: 0.9327
# Step 31500, Loss: 0.4574
# Step 31600, Loss: 0.2723
# Step 31700, Loss: 0.1876
# Step 31800, Loss: 0.1413
# Step 31900, Loss: 0.1126
# Step 32000, Loss: 0.0933
# Step 32100, Loss: 0.0795
# Step 32200, Loss: 1.7996
# Step 32300, Loss: 0.8881
# Step 32400, Loss: 0.4380
# Step 32500, Loss: 0.2641
# Step 32600, Loss: 0.1834
# Step 32700, Loss: 0.1388
# Step 32800, Loss: 0.1110
# Step 32900, Loss: 0.0922
# Step 33000, Loss: 0.0786
# Step 33100, Loss: 1.8640
# Step 33200, Loss: 0.8163
# Step 33300, Loss: 0.4165
# Step 33400, Loss: 0.2554
# Step 33500, Loss: 0.1789
# Step 33600, Loss: 0.1361
# Step 33700, Loss: 0.1092
# Step 33800, Loss: 0.0909
# Step 33900, Loss: 30.6152
# Step 34000, Loss: 1.7284
# Step 34100, Loss: 0.7855
# Step 34200, Loss: 0.4007
# Step 34300, Loss: 0.2481
# Step 34400, Loss: 0.1750
# Step 34500, Loss: 0.1337
# Step 34600, Loss: 0.1077
# Step 34700, Loss: 0.0898
# Step 34800, Loss: 20.0905
# Step 34900, Loss: 1.5723
# Step 35000, Loss: 0.7335
# Step 35100, Loss: 0.3800
# Step 35200, Loss: 0.2389
# Step 35300, Loss: 0.1701
# Step 35400, Loss: 0.1308
# Step 35500, Loss: 0.1057
# Step 35600, Loss: 0.0884
# Step 35700, Loss: 4.4507
# Step 35800, Loss: 1.4790
# Step 35900, Loss: 0.6939
# Step 36000, Loss: 0.3658
# Step 36100, Loss: 0.2325
# Step 36200, Loss: 0.1667
# Step 36300, Loss: 0.1287
# Step 36400, Loss: 0.1043
# Step 36500, Loss: 0.0874
# Step 36600, Loss: 3.1309
# Step 36700, Loss: 1.5325
# Step 36800, Loss: 0.6523
# Step 36900, Loss: 0.3509
# Step 37000, Loss: 0.2257
# Step 37100, Loss: 0.1629
# Step 37200, Loss: 0.1264
# Step 37300, Loss: 0.1027
# Step 37400, Loss: 0.0863
# Step 37500, Loss: 2.2624
# Step 37600, Loss: 1.3424
# Step 37700, Loss: 0.6121
# Step 37800, Loss: 0.3337
# Step 37900, Loss: 0.2177
# Step 38000, Loss: 0.1585
# Step 38100, Loss: 0.1236
# Step 38200, Loss: 0.1009
# Step 38300, Loss: 0.0850
# Step 38400, Loss: 2.2889
# Step 38500, Loss: 1.2477
# Step 38600, Loss: 0.5753
# Step 38700, Loss: 0.3196
# Step 38800, Loss: 0.2110
# Step 38900, Loss: 0.1548
# Step 39000, Loss: 0.1212
# Step 39100, Loss: 0.0992
# Step 39200, Loss: 0.0838
# Step 39300, Loss: 2.2601
# Step 39400, Loss: 1.1804
# Step 39500, Loss: 0.5473
# Step 39600, Loss: 0.3086
# Step 39700, Loss: 0.2057
# Step 39800, Loss: 0.1518
# Step 39900, Loss: 0.1193
# Step 40000, Loss: 0.0979
# Step 40100, Loss: 0.0829
# Step 40200, Loss: 2.1387
# Step 40300, Loss: 1.1046
# Step 40400, Loss: 0.5174
# Step 40500, Loss: 0.2987
# Step 40600, Loss: 0.2011
# Step 40700, Loss: 0.1491
# Step 40800, Loss: 0.1177
# Step 40900, Loss: 0.0968
# Step 41000, Loss: 0.0820
# Step 41100, Loss: 2.1416
# Step 41200, Loss: 1.0466
# Step 41300, Loss: 0.4969
# Step 41400, Loss: 0.2885
# Step 41500, Loss: 0.1958
# Step 41600, Loss: 0.1461
# Step 41700, Loss: 0.1157
# Step 41800, Loss: 0.0954
# Step 41900, Loss: 0.0810
# Step 42000, Loss: 1.9671
# Step 42100, Loss: 0.9708
# Step 42200, Loss: 0.4667
# Step 42300, Loss: 0.2761
# Step 42400, Loss: 0.1896
# Step 42500, Loss: 0.1424
# Step 42600, Loss: 0.1133
# Step 42700, Loss: 0.0938
# Step 42800, Loss: 0.0798
# Step 42900, Loss: 2.0406
# Step 43000, Loss: 0.9031
# Step 43100, Loss: 0.4464
# Step 43200, Loss: 0.2694
# Step 43300, Loss: 0.1861
# Step 43400, Loss: 0.1404
# Step 43500, Loss: 0.1120
# Step 43600, Loss: 0.0929
# Step 43700, Loss: 0.0792
# Step 43800, Loss: 1.8424
# Step 43900, Loss: 0.8594
# Step 44000, Loss: 0.4262
# Step 44100, Loss: 0.2591
# Step 44200, Loss: 0.1808
# Step 44300, Loss: 0.1372
# Step 44400, Loss: 0.1100
# Step 44500, Loss: 0.0914

# %% [markdown]
# # Section 5: Plot the model
# Let's see what the network learned.
# Generate 100 x values and 100 y values, each in the range (-1, 1).
# Then compute the value of `probability` (the sigmoid output of your model) using every coordinate in that grid (every pairwise combination of x and y values), and plot a "map" of those probabilities using `plt.scatter()` (check out the `c` argument).

# %%
test = [[9.899889883644900079e-01, 2.993364156690488387e-01], [-1.015288177056490326e+00, -4.436604427019936736e-01]]

prob = model(test)

print(prob)
print(test)
predicted_labels = tf.cast(prob > 0.5, tf.float32)
print(predicted_labels)
# Out:
# tf.Tensor(
# [[0.07513693]
#  [0.07513693]], shape=(2, 1), dtype=float32)
# [[0.98998898836449, 0.29933641566904884], [-1.0152881770564903, -0.4436604427019937]]
# tf.Tensor(
# [[0.]
#  [0.]], shape=(2, 1), dtype=float32)

# %%
# Your code here

# 1. Generate a grid of 100 x and 100 y values between -1 and 1
x_vals = np.linspace(-1, 1, 100)
y_vals = np.linspace(-1, 1, 100)

# 2. Create all pairwise (x, y) combinations using meshgrid and reshape
xx, yy = np.meshgrid(x_vals, y_vals)
grid_points = np.stack([xx.ravel(), yy.ravel()], axis=1)

# 3. Convert to float32 tensor for model input
grid_tensor = tf.convert_to_tensor(grid_points, dtype=tf.float32)

# 4. Compute predicted probabilities from the model
probs = model(grid_tensor)  # or model.__call__(grid_tensor)
probs = tf.squeeze(probs).numpy()  # Remove singleton dimension and convert to NumPy


# 5. Plot using plt.scatter with colors corresponding to probabilities
plt.figure(figsize=(6, 5))
plt.scatter(grid_points[:, 0], grid_points[:, 1], c=probs, cmap='viridis', s=5)
plt.colorbar(label='Probability of Boundary')
plt.title("Model Output Over Input Space")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # Section 6: TensorBoard plots
# This time, we have some more interesting TensorBoard plots than last time.
# Run TensorBoard, and look at:
#  - The loss over time in Scalars
#  - The weights, biases, and gradients over time in Distributions and Histograms
#
# The loss should decrease over time, and eventually stabilize (with some noise).
#
# The gradients for weights and biases may not go to zero, and your weights and biases may not look like they're converging.
# This is because of "bias drift" where multiple possible settings of weights and biases have the same loss value.
# To fix this, we could add a term to the loss which penalizes the model slightly based on the magnitude of the bias terms.

# %% [markdown]
# # Section 7: Again, but in Keras
# Make a Keras Sequential model which is equivalent to the one we've trained in TensorFlow.
# Train it on the same dataset, and again plot its output in the same way.
#
# Hints:
#  - This won't take nearly as long as the previous sections
#  - You don't need to use `keras.utils.to_categorical` since this is binary classification.
#  - The appropriate loss function is 'binary_crossentropy'
#  - To implement the same loss weighting, use `class_weight={0: 1.0, 1:20.0}` in `model.fit()`
#  - You can get the outputs of the model over the entire grid at once with `model.predict()`

# %% [markdown]
# ### 7.1: Build a model
# Use `keras.models.Sequential` to build the same FCN as before.

# %%
# Your code here

# %% [markdown]
# ### 7.2: Define an optimizer and compile the model

# %%
# Your code here

# %% [markdown]
# ### 7.3: Fit the model

# %%
# Your code here

# %% [markdown]
# ### 7.4: Plot the model

# %%
# Your code here
