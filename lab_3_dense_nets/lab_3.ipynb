# %% [markdown]
# # Lab 3: Mapping with Fully-Connected Networks (3)
# Blocks of dense layers are really good at memorizing patterns.
# This week we'll step outside the traditional "prediction" regime of machine learning and use a fully-connected network (FCN) to represent a 2-D scene in its weight by interpolating between known points.
#
# Throughout, you should be impressed by two (related) properties of dense neural nets:
#  - They have high enough capacity to entirely memorize complex patterns
#  - They are sufficiently nonlinear to build these patterns up from simple inputs (like (x, y) coordinates in this case)

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # Pointcloud mapping
#
# ![full scene](./images/full_scene.png)
#
# ### The problem
# Imagine there is a square (2-D) room with four walls and several square and circular objects in it.
# We put laser distance sensors around the room, which shoot rays that continue until they hit an object or a wall and report the distance, with limited angular and radial resolution.
# We want to use this limited data to produce a full 2-D reconstruction of the scene, filling in points the sensors haven't observed with likely values (in essence, interpolating).
#
# ### The data
# We know that every ray that there's an object at the point each ray hit, and we also know that there's no object between the camera and the contact point.
# The data is provided as (x, y) pairs, where some points correspond to places we know are on object boundaries (shown in green above) and points we know are not inside objects (shown in red above).
#
# These points come in two data files: `data/positives.txt` for points on the edge of objects, and `data/negatives.txt` for points outside of objects.
# To generate these files, run `make_data.py`.
#
# (Check out the code if you want to see how the points are generated, but don't change anything!)
#
# ### The model
# We want to store a full description of the scene in the weights of a neural network.
# To do this, we'll train a FCN to classify (x, y) points by whether or not they are the edge of a wall or object.
# Then, we can draw the scene by sampling (x, y) pairs and drawing the model's output.
# So, the network has "memorized" where the objects and walls are, and what their shapes are.

# %% [markdown]
# # Section 1: Load the data
# Load the data using `np.loadtxt()` (default arguments should work), then convert it to a usable format with a feature array and label array, which is 1 if a point is the edge of an object and 0 if it is not.
#
# Functions to look at:
#  - `np.loadtxt`
#  - `np.concatenate`

# %%
# Your code here

# Load the data from the text files
positive_data = np.loadtxt(r'data/positives.txt')  # Each line should be a coordinate (x, y)
negative_data = np.loadtxt(r'data/negatives.txt')  # Same format for negative data

# Create feature arrays (coordinates)
positive_features = positive_data  # Shape: (n_positive, 2) where each row is (x, y)
negative_features = negative_data  # Shape: (n_negative, 2)

# Create label arrays (1 for positive, 0 for negative)
positive_labels = np.ones(positive_features.shape[0])  # Label 1 for positive data
negative_labels = np.zeros(negative_features.shape[0])  # Label 0 for negative data

# Combine the positive and negative data into a single dataset
features = np.concatenate((positive_features, negative_features), axis=0)
labels = np.concatenate((positive_labels, negative_labels), axis=0)

# Now, `features` contains all the coordinates and `labels` contains the corresponding labels

# %% [markdown]
# # Section 2: Build a data pipeline
# Set up a `tf.data.Dataset` and a `tf.summary.SummaryWriter`.
# This time, there's no test set, just a single dataset. You may want to use the `repeat` method on the dataset for the number of desired epochs. If so, call it after caching so as not to store redundant data.

# %%
# Assume features and labels are already created as NumPy arrays
# features: shape (N, 2), labels: shape (N,)

# Create the dataset
dataset = tf.data.Dataset.from_tensor_slices((features, labels))

# Shuffle, cache, and batch the dataset
batch_size = 32
dataset = dataset.shuffle(buffer_size=len(features))  # Shuffle the data
dataset = dataset.batch(batch_size)          # Batch the data
dataset = dataset.cache()  
dataset = dataset.repeat(40)

# Set up the TensorBoard SummaryWriter
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
summary_writer = tf.summary.create_file_writer(log_dir)

# Optionally, log some sample data (e.g., first batch)
for batch_features, batch_labels in dataset.take(1):
    with summary_writer.as_default():
        tf.summary.scalar("batch_sample_label", batch_labels[0], step=0)
        tf.summary.histogram("batch_features", batch_features, step=0)

# %% [markdown]
# # Section 3: Build a model graph
# The model is a simple fully-connected neural network with four hidden layers, each with 64 units, and an output layer that performs binary classification with sigmoid activation.
# Recall that the input is just a pair (x, y).
#
# Functions to look at throughout:
#  - `tf.cast`
#  - `tf.expand_dims`
#  - `tf.squeeze`
#  - arithmetic operations

# %% [markdown]
# ### 3.1: Class to make dense layers
# It's tedious (and bad design) to explicitly write out every variable, matrix multiplication, etc.
# Instead, it's common to define classes that create one of a structure you expect to repeat in your model.
#
# Write a `tf.Module` class called `Dense`, which has its signature and scopes defined as a stub below.
# When called, it should add variables and operations to the graph which implement a single dense layer.
#
# If `do_activation` is True, it should apply ReLU activation to the computed values.
# To do this, you can use `tf.nn.relu`.

# %%
class Dense(tf.Module):
    '''
    Creates a dense layer module.

    Parameters
    ----------
    dim_input: int
        Number of features in the input representation.
    dim_output: int
        Number of features in the output representation.
    do_activation: bool
        Whether or not to apply ReLU activation.
    postfix: string
        Postfix on name scopes in this layer.
    name: string
        Name of layer.
    '''
    def __init__(self, dim_input, dim_output, do_activation=True, postfix='', name=None):
        super().__init__(name=name)
        self.do_activation = do_activation
        self.dim_input = dim_input
        self.dim_output = dim_output

        with tf.name_scope('dense' + postfix):
            # Weight matrix shape: [input_dim, output_dim]

            self.w = tf.Variable(
                tf.initializers.he_uniform()(shape=(dim_input, dim_output), dtype=tf.float64),
                name='weights',
                dtype=tf.float64
            )
            # Bias vector shape: [output_dim]
            self.b = tf.Variable(
                tf.zeros_initializer()(shape=(dim_output,), dtype=tf.float64),
                name='bias',
                dtype = tf.float64
            )

    def __call__(self, x):
        z = tf.matmul(x, self.w) + self.b
        if self.do_activation:
            return tf.nn.relu(z)
        return z

# %% [markdown]
# ### 3.2: Class to make neural network
# Use the `Dense` class to make four dense layers contained as fields in a `tf.Module` class called `FeedForward`.
# Each should have 64 units, the correct input dimensions, and a distinct (and meaningful) postfix.

# %% [markdown]
# #### 3.2.1: Compute logit
# Use the `Dense` class to make a final dense layer with `dim_output=1` to compute the final logit. You'll want to put this in a method called `logits` which should take in `self` and an input.

# %% [markdown]
# #### 3.2.2: Compute class probability for output
# Use `tf.sigmoid` to compute the probability that the input coordinate is a boundary point.
# We will not use this for the loss, just for the output. You'll want to put this in the `__call__` method.

# %%
class FeedForward(tf.Module):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.dense1 = Dense(dim_input=2, dim_output=64, do_activation=True, postfix='_1')
        self.dense2 = Dense(dim_input=64, dim_output=64, do_activation=True, postfix='_2')
        self.dense3 = Dense(dim_input=64, dim_output=64, do_activation=True, postfix='_3')
        self.dense4 = Dense(dim_input=64, dim_output=64, do_activation=True, postfix='_4')
        # Output layer without activation (logit)
        self.output_layer = Dense(dim_input=64, dim_output=1, do_activation=False, postfix='_out')

    def logits(self, x):
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)
        x = self.dense4(x)
        return self.output_layer(x)

    def __call__(self, x):
        # Get logits and pass through sigmoid to get probabilities
        logit = self.logits(x)
        return tf.sigmoid(logit)
    
    def _loss(self, x, y):
        # Ensure labels are the right shape (batch_size, 1)
        # y = tf.cast(tf.expand_dims(y, axis=1), tf.float32)
        logit = self.logits(x)
        logit = tf.squeeze(logit)
        loss_per_example = tf.nn.weighted_cross_entropy_with_logits(
            labels=y,
            logits=logit,
            pos_weight=20.0  
        )

        # reduce mean
        return tf.reduce_mean(loss_per_example)

# %% [markdown]
# ### 3.3: Compute weighted cross-entropy loss
# There are about 33 times as many non-boundary coordinates as there are boundary coordinates.
# To prevent the network from just learning to predict that every coordinate is not a boundary, we should weight the loss function to consider boundary pixels more heavily.
#
# To do this, use `tf.nn.weighted_cross_entropy_with_logits()` on the logits computed before, plus the input label, and a positive weight of 20.
# Then, produce the mean loss for the batch with `tf.reduce_mean`. Put this in a `_loss` method.

# %% [markdown]
# ### 3.4: Optimizer and gradients
# Make an optimizer (I used `tf.optimizers.SGD` with `learning_rate=2e-3` and `momentum=0.9`).
# Then write a train method (taking in a model, input, output, and step), that represents one step of training, where you explicitly compute the gradients in a variable called `gradients` (so we can plot them below) and make an operation that applies those gradients to the graph.
#
# Note: don't use `optimizer.minimize`, which will result in computing the gradients twice since we already have them from `GradientTape.gradient`. Add a summary scalar to plot loss in TensorBoard.

# %%
# Your code here
optimizer = tf.optimizers.SGD(learning_rate=2e-3, momentum=0.9)


def train_step(model, x, y, step, summary_writer):
    with tf.GradientTape() as tape:
        loss = model._loss(x, y)
    
    # Compute gradients with respect to trainable variables
    gradients = tape.gradient(loss, model.trainable_variables)
    
    # Apply gradients
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    # Log the loss to TensorBoard
    with summary_writer.as_default():
        tf.summary.scalar('train_loss', loss, step=step)
        for gradient, variable in zip(gradients, model.trainable_variables):
            if variable.name and gradient is not None:
                tf.summary.histogram('gradients/' + variable.name, tf.norm(gradient), step=step)
                tf.summary.histogram('variables/' + variable.name, tf.norm(variable), step=step)
    return loss, gradients

# %% [markdown]
# #### 3.4.1: Plot variables and gradients
# You don't need to do this for every model, but it's illustrative to do at least once. I've written the code for this below, with a pattern borrowed from http://matpalm.com/blog/viz_gradient_norms/. Put this code snippet under the same `with` block where you add your loss summary scalar.
#
# ```
# for gradient, variable in zip(gradients, model.trainable_variables):
#     if variable.name and gradient is not None:
#         tf.summary.histogram('gradients/' + variable.name, tf.norm(gradient), step=i)
#         tf.summary.histogram('variables/' + variable.name, tf.norm(variable), step=i)
# ```

# %%
# Your code here

# %% [markdown]
# # Section 4: train the model
# Same as last time, except there's no test set.
# You don't need to distinguish between epochs and steps here.
#
# I used 50 epochs, and got a final cross-entropy loss of about 0.4.
# You might not need to use this many epochs to get reasonable results, but more will get crisper results.
#
# This might take a while on CPUs, so if it's taking too long, think about:
#  - Using Google Colaboratory
#  - Increasing your batch size
#  - Reducing the frequency with which you run summary ops
#
# Watching plots, histograms, etc in TensorBoard as the model trains can be fun.

# %%
# Your code here

# Instantiate model and summary writer
model = FeedForward()
summary_writer = tf.summary.create_file_writer("logs/train")


step = 0
for i in range(1): #dataset is repeated 40 times so we can do 1 here
    print(f"epoch {i}:")
    for batch_features, batch_labels in dataset:
        loss, gradients = train_step(model, batch_features, batch_labels, step, summary_writer)

        # Optionally print progress
        if step % 100 == 0:
            print(f"Step {step}, Loss: {loss.numpy():.4f}")

        step += 1
# Out:
# epoch 0:
# Step 0, Loss: 0.9548
# Step 100, Loss: 1.2968
# Step 200, Loss: 0.3303
# Step 300, Loss: 1.1710
# Step 400, Loss: 0.9865
# Step 500, Loss: 1.9847
# Step 600, Loss: 0.4099
# Step 700, Loss: 0.3795
# Step 800, Loss: 1.3787
# Step 900, Loss: 0.4237
# Step 1000, Loss: 0.9498
# Step 1100, Loss: 0.3143
# Step 1200, Loss: 0.5019
# Step 1300, Loss: 1.0498
# Step 1400, Loss: 0.5390
# Step 1500, Loss: 0.4558
# Step 1600, Loss: 0.3459
# Step 1700, Loss: 0.8178
# Step 1800, Loss: 2.0229
# Step 1900, Loss: 0.7983
# Step 2000, Loss: 0.3292
# Step 2100, Loss: 1.3497
# Step 2200, Loss: 0.8316
# Step 2300, Loss: 0.9342
# Step 2400, Loss: 0.5905
# Step 2500, Loss: 0.3745
# Step 2600, Loss: 2.2464
# Step 2700, Loss: 0.9553
# Step 2800, Loss: 0.2420
# Step 2900, Loss: 0.9546
# Step 3000, Loss: 0.4839
# Step 3100, Loss: 0.4658
# Step 3200, Loss: 1.3308
# Step 3300, Loss: 1.0815
# Step 3400, Loss: 1.7168
# Step 3500, Loss: 0.8141
# Step 3600, Loss: 0.7224
# Step 3700, Loss: 0.8396
# Step 3800, Loss: 0.4594
# Step 3900, Loss: 0.2592
# Step 4000, Loss: 1.0043
# Step 4100, Loss: 0.5570
# Step 4200, Loss: 1.2317
# Step 4300, Loss: 0.3970
# Step 4400, Loss: 1.0047
# Step 4500, Loss: 1.0977
# Step 4600, Loss: 1.1430
# Step 4700, Loss: 1.3238
# Step 4800, Loss: 0.7195
# Step 4900, Loss: 1.4921
# Step 5000, Loss: 0.4727
# Step 5100, Loss: 0.8852
# Step 5200, Loss: 0.4608
# Step 5300, Loss: 0.9174
# Step 5400, Loss: 1.8084
# Step 5500, Loss: 0.3998
# Step 5600, Loss: 0.3300
# Step 5700, Loss: 0.6925
# Step 5800, Loss: 0.5129
# Step 5900, Loss: 0.2253
# Step 6000, Loss: 0.5081
# Step 6100, Loss: 0.3348
# Step 6200, Loss: 0.3149
# Step 6300, Loss: 0.8644
# Step 6400, Loss: 1.3671
# Step 6500, Loss: 0.3438
# Step 6600, Loss: 0.6639
# Step 6700, Loss: 0.5027
# Step 6800, Loss: 0.7519
# Step 6900, Loss: 0.6452
# Step 7000, Loss: 0.9956
# Step 7100, Loss: 0.3263
# Step 7200, Loss: 0.5695
# Step 7300, Loss: 0.6987
# Step 7400, Loss: 0.7269
# Step 7500, Loss: 0.7545
# Step 7600, Loss: 0.2381
# Step 7700, Loss: 0.2773
# Step 7800, Loss: 0.8417
# Step 7900, Loss: 0.2321
# Step 8000, Loss: 0.4563
# Step 8100, Loss: 0.4597
# Step 8200, Loss: 0.4929
# Step 8300, Loss: 0.4123
# Step 8400, Loss: 0.8882
# Step 8500, Loss: 0.2305
# Step 8600, Loss: 0.5432
# Step 8700, Loss: 0.3051
# Step 8800, Loss: 0.7782
# Step 8900, Loss: 0.6586
# Step 9000, Loss: 0.3523
# Step 9100, Loss: 0.3274
# Step 9200, Loss: 0.8092
# Step 9300, Loss: 0.3941
# Step 9400, Loss: 0.5938
# Step 9500, Loss: 0.6244
# Step 9600, Loss: 0.6675
# Step 9700, Loss: 0.5142
# Step 9800, Loss: 0.5376
# Step 9900, Loss: 0.3029
# Step 10000, Loss: 0.2875
# Step 10100, Loss: 0.3698
# Step 10200, Loss: 0.2053
# Step 10300, Loss: 0.4946
# Step 10400, Loss: 0.8401
# Step 10500, Loss: 1.2342
# Step 10600, Loss: 0.5638
# Step 10700, Loss: 0.3184
# Step 10800, Loss: 0.1537
# Step 10900, Loss: 0.7851
# Step 11000, Loss: 1.2780
# Step 11100, Loss: 0.1862
# Step 11200, Loss: 0.4213
# Step 11300, Loss: 0.1389
# Step 11400, Loss: 0.3978
# Step 11500, Loss: 0.5893
# Step 11600, Loss: 0.9030
# Step 11700, Loss: 0.5529
# Step 11800, Loss: 0.1163
# Step 11900, Loss: 0.7357
# Step 12000, Loss: 0.9549
# Step 12100, Loss: 0.4960
# Step 12200, Loss: 0.1979
# Step 12300, Loss: 0.2616
# Step 12400, Loss: 0.3646
# Step 12500, Loss: 0.3597
# Step 12600, Loss: 0.2820
# Step 12700, Loss: 0.1691
# Step 12800, Loss: 0.6473
# Step 12900, Loss: 0.5125
# Step 13000, Loss: 0.4602
# Step 13100, Loss: 0.5926
# Step 13200, Loss: 0.3147
# Step 13300, Loss: 0.6748
# Step 13400, Loss: 0.6261
# Step 13500, Loss: 0.5115
# Step 13600, Loss: 0.3290
# Step 13700, Loss: 0.6424
# Step 13800, Loss: 0.7546
# Step 13900, Loss: 0.6863
# Step 14000, Loss: 1.2032
# Step 14100, Loss: 0.9060
# Step 14200, Loss: 0.3098
# Step 14300, Loss: 0.9256
# Step 14400, Loss: 0.2859
# Step 14500, Loss: 0.6009
# Step 14600, Loss: 1.1911
# Step 14700, Loss: 0.2161
# Step 14800, Loss: 0.4733
# Step 14900, Loss: 0.1440
# Step 15000, Loss: 0.1839
# Step 15100, Loss: 0.5319
# Step 15200, Loss: 1.4796
# Step 15300, Loss: 0.9002
# Step 15400, Loss: 0.2323
# Step 15500, Loss: 0.2694
# Step 15600, Loss: 0.3943
# Step 15700, Loss: 0.4190
# Step 15800, Loss: 0.3153
# Step 15900, Loss: 0.1874
# Step 16000, Loss: 0.2388
# Step 16100, Loss: 0.1441
# Step 16200, Loss: 0.4584
# Step 16300, Loss: 0.5031
# Step 16400, Loss: 0.2834
# Step 16500, Loss: 0.6330
# Step 16600, Loss: 0.5996
# Step 16700, Loss: 0.4295
# Step 16800, Loss: 0.2178
# Step 16900, Loss: 0.3529
# Step 17000, Loss: 0.1647
# Step 17100, Loss: 0.5303
# Step 17200, Loss: 0.6260
# Step 17300, Loss: 0.4544
# Step 17400, Loss: 0.4532
# Step 17500, Loss: 0.4376
# Step 17600, Loss: 0.8669
# Step 17700, Loss: 0.5793
# Step 17800, Loss: 0.2957
# Step 17900, Loss: 0.3059
# Step 18000, Loss: 0.6805
# Step 18100, Loss: 0.2323
# Step 18200, Loss: 0.2799
# Step 18300, Loss: 0.3962
# Step 18400, Loss: 0.5356
# Step 18500, Loss: 0.3105
# Step 18600, Loss: 0.3777
# Step 18700, Loss: 0.4962
# Step 18800, Loss: 0.5453
# Step 18900, Loss: 0.1998
# Step 19000, Loss: 0.1752
# Step 19100, Loss: 0.6410
# Step 19200, Loss: 0.3794
# Step 19300, Loss: 0.5489
# Step 19400, Loss: 0.4884
# Step 19500, Loss: 0.3998
# Step 19600, Loss: 0.2704
# Step 19700, Loss: 0.4488
# Step 19800, Loss: 0.2300
# Step 19900, Loss: 0.4737
# Step 20000, Loss: 0.6620
# Step 20100, Loss: 0.3679
# Step 20200, Loss: 0.6752
# Step 20300, Loss: 0.2781
# Step 20400, Loss: 0.4422
# Step 20500, Loss: 0.4740
# Step 20600, Loss: 0.3605
# Step 20700, Loss: 0.3147
# Step 20800, Loss: 0.5947
# Step 20900, Loss: 0.7007
# Step 21000, Loss: 0.7650
# Step 21100, Loss: 0.6691
# Step 21200, Loss: 0.2840
# Step 21300, Loss: 0.9246
# Step 21400, Loss: 0.2362
# Step 21500, Loss: 0.6339
# Step 21600, Loss: 0.2129
# Step 21700, Loss: 0.6065
# Step 21800, Loss: 0.3912
# Step 21900, Loss: 1.5367
# Step 22000, Loss: 0.1744
# Step 22100, Loss: 0.4996
# Step 22200, Loss: 0.1762
# Step 22300, Loss: 0.2371
# Step 22400, Loss: 0.9030
# Step 22500, Loss: 0.1460
# Step 22600, Loss: 0.5045
# Step 22700, Loss: 0.1745
# Step 22800, Loss: 0.3643
# Step 22900, Loss: 0.5125
# Step 23000, Loss: 0.4077
# Step 23100, Loss: 0.3034
# Step 23200, Loss: 0.2542
# Step 23300, Loss: 0.2152
# Step 23400, Loss: 1.9579
# Step 23500, Loss: 0.5054
# Step 23600, Loss: 2.0616
# Step 23700, Loss: 0.4664
# Step 23800, Loss: 0.1984
# Step 23900, Loss: 0.4137
# Step 24000, Loss: 0.0854
# Step 24100, Loss: 1.1996
# Step 24200, Loss: 0.2416
# Step 24300, Loss: 0.5076
# Step 24400, Loss: 0.9049
# Step 24500, Loss: 0.3022
# Step 24600, Loss: 0.3348
# Step 24700, Loss: 0.7577
# Step 24800, Loss: 0.3534
# Step 24900, Loss: 0.2201
# Step 25000, Loss: 0.6377
# Step 25100, Loss: 0.2953
# Step 25200, Loss: 0.5233
# Step 25300, Loss: 0.3031
# Step 25400, Loss: 0.4390
# Step 25500, Loss: 0.2140
# Step 25600, Loss: 0.2338
# Step 25700, Loss: 0.2469
# Step 25800, Loss: 0.1071
# Step 25900, Loss: 0.1773
# Step 26000, Loss: 0.4140
# Step 26100, Loss: 0.1122
# Step 26200, Loss: 0.2804
# Step 26300, Loss: 0.1798
# Step 26400, Loss: 0.2810
# Step 26500, Loss: 0.6342
# Step 26600, Loss: 0.1483
# Step 26700, Loss: 0.3681
# Step 26800, Loss: 0.1419
# Step 26900, Loss: 0.4524
# Step 27000, Loss: 0.5877
# Step 27100, Loss: 0.2745
# Step 27200, Loss: 0.1371
# Step 27300, Loss: 0.6942
# Step 27400, Loss: 0.5077
# Step 27500, Loss: 0.6711
# Step 27600, Loss: 0.1891
# Step 27700, Loss: 0.5595
# Step 27800, Loss: 0.0486
# Step 27900, Loss: 0.2887
# Step 28000, Loss: 0.4108
# Step 28100, Loss: 0.4047
# Step 28200, Loss: 0.9376
# Step 28300, Loss: 0.2932
# Step 28400, Loss: 0.1448
# Step 28500, Loss: 0.2737
# Step 28600, Loss: 0.3816
# Step 28700, Loss: 0.4140
# Step 28800, Loss: 1.0043
# Step 28900, Loss: 0.2460
# Step 29000, Loss: 0.3294
# Step 29100, Loss: 0.5453
# Step 29200, Loss: 0.2100
# Step 29300, Loss: 0.7393
# Step 29400, Loss: 0.2540
# Step 29500, Loss: 1.5730
# Step 29600, Loss: 0.2438
# Step 29700, Loss: 0.2045
# Step 29800, Loss: 0.5894
# Step 29900, Loss: 0.5151
# Step 30000, Loss: 0.1934
# Step 30100, Loss: 0.2494
# Step 30200, Loss: 0.5630
# Step 30300, Loss: 0.2752
# Step 30400, Loss: 0.2641
# Step 30500, Loss: 0.3977
# Step 30600, Loss: 0.3591
# Step 30700, Loss: 0.1981
# Step 30800, Loss: 0.2851
# Step 30900, Loss: 0.1525
# Step 31000, Loss: 0.2645
# Step 31100, Loss: 0.7946
# Step 31200, Loss: 0.3091
# Step 31300, Loss: 0.1837
# Step 31400, Loss: 0.2683
# Step 31500, Loss: 0.6038
# Step 31600, Loss: 0.3332
# Step 31700, Loss: 0.3435
# Step 31800, Loss: 0.3236
# Step 31900, Loss: 0.3020
# Step 32000, Loss: 0.1363
# Step 32100, Loss: 0.1752
# Step 32200, Loss: 0.3601
# Step 32300, Loss: 0.3224
# Step 32400, Loss: 0.2033
# Step 32500, Loss: 0.3559
# Step 32600, Loss: 0.2748
# Step 32700, Loss: 0.0467
# Step 32800, Loss: 0.2047
# Step 32900, Loss: 0.2935
# Step 33000, Loss: 0.3201
# Step 33100, Loss: 0.4970
# Step 33200, Loss: 0.4410
# Step 33300, Loss: 0.4362
# Step 33400, Loss: 0.3914
# Step 33500, Loss: 0.3067
# Step 33600, Loss: 0.4283
# Step 33700, Loss: 0.1426
# Step 33800, Loss: 0.4915
# Step 33900, Loss: 0.6017
# Step 34000, Loss: 0.1949
# Step 34100, Loss: 0.6377
# Step 34200, Loss: 0.1636
# Step 34300, Loss: 0.4830
# Step 34400, Loss: 0.0881
# Step 34500, Loss: 0.1968
# Step 34600, Loss: 0.0883
# Step 34700, Loss: 0.2797
# Step 34800, Loss: 0.5048
# Step 34900, Loss: 0.3284
# Step 35000, Loss: 0.1063
# Step 35100, Loss: 0.3446
# Step 35200, Loss: 0.5077
# Step 35300, Loss: 0.2332
# Step 35400, Loss: 0.3200
# Step 35500, Loss: 0.7178
# Step 35600, Loss: 0.4813
# Step 35700, Loss: 0.2707

# %% [markdown]
# # Section 5: Plot the model
# Let's see what the network learned.
# Generate 100 x values and 100 y values, each in the range (-1, 1).
# Then compute the value of `probability` (the sigmoid output of your model) using every coordinate in that grid (every pairwise combination of x and y values), and plot a "map" of those probabilities using `plt.scatter()` (check out the `c` argument).

# %%
# Your code here

# 1. Generate a grid of 100 x and 100 y values between -1 and 1
x_vals = np.linspace(-1, 1, 100)
y_vals = np.linspace(-1, 1, 100)

# 2. Create all pairwise (x, y) combinations using meshgrid and reshape
xx, yy = np.meshgrid(x_vals, y_vals)
grid_points = np.stack([xx.ravel(), yy.ravel()], axis=1)

# 3. Convert to float32 tensor for model input
grid_tensor = tf.convert_to_tensor(grid_points)

# 4. Compute predicted probabilities from the model
probs = model(grid_tensor)  # or model.__call__(grid_tensor)
probs = tf.squeeze(probs).numpy()  # Remove singleton dimension and convert to NumPy


# 5. Plot using plt.scatter with colors corresponding to probabilities
plt.figure(figsize=(6, 5))
plt.scatter(grid_points[:, 0], grid_points[:, 1], c=probs, cmap='viridis', s=5)
plt.colorbar(label='Probability of Boundary')
plt.title("Model Output Over Input Space")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # Section 6: TensorBoard plots
# This time, we have some more interesting TensorBoard plots than last time.
# Run TensorBoard, and look at:
#  - The loss over time in Scalars
#  - The weights, biases, and gradients over time in Distributions and Histograms
#
# The loss should decrease over time, and eventually stabilize (with some noise).
#
# The gradients for weights and biases may not go to zero, and your weights and biases may not look like they're converging.
# This is because of "bias drift" where multiple possible settings of weights and biases have the same loss value.
# To fix this, we could add a term to the loss which penalizes the model slightly based on the magnitude of the bias terms.

# %% [markdown]
# # Section 7: Again, but in Keras
# Make a Keras Sequential model which is equivalent to the one we've trained in TensorFlow.
# Train it on the same dataset, and again plot its output in the same way.
#
# Hints:
#  - This won't take nearly as long as the previous sections
#  - You don't need to use `keras.utils.to_categorical` since this is binary classification.
#  - The appropriate loss function is 'binary_crossentropy'
#  - To implement the same loss weighting, use `class_weight={0: 1.0, 1:20.0}` in `model.fit()`
#  - You can get the outputs of the model over the entire grid at once with `model.predict()`

# %% [markdown]
# ### 7.1: Build a model
# Use `keras.models.Sequential` to build the same FCN as before.

# %%
model = keras.Sequential([
    layers.Input(shape=(2,), dtype=tf.float64),
    layers.Dense(64, activation='relu', kernel_initializer='he_uniform', dtype=tf.float64),
    layers.Dense(64, activation='relu', kernel_initializer='he_uniform', dtype=tf.float64),
    layers.Dense(64, activation='relu', kernel_initializer='he_uniform', dtype=tf.float64),
    layers.Dense(64, activation='relu', kernel_initializer='he_uniform', dtype=tf.float64),
    layers.Dense(1, activation='sigmoid', dtype=tf.float64)
])

# %% [markdown]
# ### 7.2: Define an optimizer and compile the model

# %%
# Your code here
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.1),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### 7.3: Fit the model

# %%
steps_per_epoch = int(len(features) / batch_size)

model.fit(
    dataset,
    steps_per_epoch=steps_per_epoch,
    epochs=50,
)
# Out:
# Epoch 1/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9707 - loss: 0.1266
# Epoch 2/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - accuracy: 0.9708 - loss: 0.1230
# Epoch 3/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - accuracy: 0.9710 - loss: 0.1196
# Epoch 4/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 948us/step - accuracy: 0.9710 - loss: 0.1172
# Epoch 5/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - accuracy: 0.9710 - loss: 0.1140
# Epoch 6/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 953us/step - accuracy: 0.9712 - loss: 0.1088
# Epoch 7/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - accuracy: 0.9711 - loss: 0.1045
# Epoch 8/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 947us/step - accuracy: 0.9713 - loss: 0.1003
# Epoch 9/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 950us/step - accuracy: 0.9718 - loss: 0.0967
# Epoch 10/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 946us/step - accuracy: 0.9715 - loss: 0.0949
# Epoch 11/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - accuracy: 0.9716 - loss: 0.0920
# Epoch 12/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9705 - loss: 0.0911
# Epoch 13/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - accuracy: 0.9709 - loss: 0.0897
# Epoch 14/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - accuracy: 0.9703 - loss: 0.0878
# Epoch 15/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - accuracy: 0.9698 - loss: 0.0874
# Epoch 16/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - accuracy: 0.9709 - loss: 0.0855
# Epoch 17/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9709 - loss: 0.0842
# Epoch 18/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - accuracy: 0.9705 - loss: 0.0833
# Epoch 19/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.9713 - loss: 0.0815
# Epoch 20/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - accuracy: 0.9711 - loss: 0.0813
# Epoch 21/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9710 - loss: 0.0804
# Epoch 22/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9713 - loss: 0.0792
# Epoch 23/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - accuracy: 0.9714 - loss: 0.0782
# Epoch 24/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.9711 - loss: 0.0780
# Epoch 25/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - accuracy: 0.9717 - loss: 0.0770
# Epoch 26/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - accuracy: 0.9718 - loss: 0.0760
# Epoch 27/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9722 - loss: 0.0757
# Epoch 28/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - accuracy: 0.9719 - loss: 0.0753
# Epoch 29/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - accuracy: 0.9721 - loss: 0.0741
# Epoch 30/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - accuracy: 0.9719 - loss: 0.0743
# Epoch 31/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step - accuracy: 0.9716 - loss: 0.0742
# Epoch 32/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - accuracy: 0.9722 - loss: 0.0732
# Epoch 33/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - accuracy: 0.9721 - loss: 0.0725
# Epoch 34/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9724 - loss: 0.0722
# Epoch 35/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - accuracy: 0.9721 - loss: 0.0723
# Epoch 36/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9722 - loss: 0.0719
# Epoch 37/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.9727 - loss: 0.0716
# Epoch 38/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9722 - loss: 0.0713
# Epoch 39/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step - accuracy: 0.9720 - loss: 0.0709
# Epoch 40/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - accuracy: 0.9716 - loss: 0.0704
# Epoch 41/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 0s 58us/step - accuracy: 0.9744 - loss: 0.0698
# Epoch 42/50
# 209/892 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9700 - loss: 0.0706
# c:\Users\shepa\Desktop\cs12\tf-env\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - accuracy: 0.9709 - loss: 0.0705
# Epoch 43/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - accuracy: 0.9727 - loss: 0.0702
# Epoch 44/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - accuracy: 0.9723 - loss: 0.0697
# Epoch 45/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 956us/step - accuracy: 0.9726 - loss: 0.0689
# Epoch 46/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 966us/step - accuracy: 0.9726 - loss: 0.0691
# Epoch 47/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - accuracy: 0.9727 - loss: 0.0681
# Epoch 48/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - accuracy: 0.9731 - loss: 0.0674
# Epoch 49/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9732 - loss: 0.0667
# Epoch 50/50
# 892/892 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9728 - loss: 0.0661

# %% [markdown]
# ### 7.4: Plot the model

# %%
probs = model.predict(grid_points)


probs = probs.reshape(xx.shape)
plt.contourf(xx, yy, probs, levels=50, cmap='RdBu')
plt.colorbar()
plt.title("Model predictions")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step
